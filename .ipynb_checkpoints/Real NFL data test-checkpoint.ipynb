# %%
import pandas as pd
import nflreadpy as nfl
from collections import Counter
print(dir(nfl))
from playoffs import playoff_field
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'cache', 'clear_cache', 'config', 'downloader', 'get_current_season', 'get_current_week', 'load_combine', 'load_contracts', 'load_depth_charts', 'load_draft_picks', 'load_ff_opportunity', 'load_ff_playerids', 'load_ff_rankings', 'load_ffverse', 'load_ftn_charting', 'load_injuries', 'load_nextgen_stats', 'load_officials', 'load_participation', 'load_pbp', 'load_pfr_advstats', 'load_player_stats', 'load_players', 'load_rosters', 'load_rosters_weekly', 'load_schedules', 'load_snap_counts', 'load_stats', 'load_team_stats', 'load_teams', 'load_trades', 'utils_date', 'version']

# %%
sch = nfl.load_schedules([2023])
# convert to pandas if needed
if not isinstance(sch, pd.DataFrame):
    sch = sch.to_pandas()

print("SCHEDULE COLUMNS:")
print(list(sch.columns))
print("\nSCHEDULE SAMPLE:")
print(sch.head(3))
# Out:
# SCHEDULE COLUMNS:
# ['game_id', 'season', 'game_type', 'week', 'gameday', 'weekday', 'gametime', 'away_team', 'away_score', 'home_team', 'home_score', 'location', 'result', 'total', 'overtime', 'old_game_id', 'gsis', 'nfl_detail_id', 'pfr', 'pff', 'espn', 'ftn', 'away_rest', 'home_rest', 'away_moneyline', 'home_moneyline', 'spread_line', 'away_spread_odds', 'home_spread_odds', 'total_line', 'under_odds', 'over_odds', 'div_game', 'roof', 'surface', 'temp', 'wind', 'away_qb_id', 'home_qb_id', 'away_qb_name', 'home_qb_name', 'away_coach', 'home_coach', 'referee', 'stadium_id', 'stadium']
#
# SCHEDULE SAMPLE:
#            game_id  season game_type  week     gameday   weekday gametime  \
# 0   2023_01_DET_KC    2023       REG     1  2023-09-07  Thursday    20:20
# 1  2023_01_CAR_ATL    2023       REG     1  2023-09-10    Sunday    13:00
# 2  2023_01_HOU_BAL    2023       REG     1  2023-09-10    Sunday    13:00
#
#   away_team  away_score home_team  ...  wind  away_qb_id  home_qb_id  \
# 0       DET          21        KC  ...   NaN  00-0033106  00-0033873
# 1       CAR          10       ATL  ...   NaN  00-0039150  00-0038122
# 2       HOU           9       BAL  ...   NaN  00-0039163  00-0034796
#
#    away_qb_name     home_qb_name    away_coach     home_coach      referee  \
# 0    Jared Goff  Patrick Mahomes  Dan Campbell      Andy Reid  John Hussey
# 1   Bryce Young   Desmond Ridder   Frank Reich   Arthur Smith  Brad Rogers
# 2   C.J. Stroud    Lamar Jackson  DeMeco Ryans  John Harbaugh    Tra Blake
#
#   stadium_id                          stadium
# 0      KAN00  GEHA Field at Arrowhead Stadium
# 1      ATL97            Mercedes-Benz Stadium
# 2      BAL00                 M&T Bank Stadium
#
# [3 rows x 46 columns]

# %%
teams = nfl.load_teams()
if not isinstance(teams, pd.DataFrame):
    teams = teams.to_pandas()

print("TEAM COLUMNS:")
print(list(teams.columns))
print("\nTEAM SAMPLE:")
print(teams.head(40))
# Out:
# TEAM COLUMNS:
# ['team_abbr', 'team_name', 'team_id', 'team_nick', 'team_conf', 'team_division', 'team_color', 'team_color2', 'team_color3', 'team_color4', 'team_logo_wikipedia', 'team_logo_espn', 'team_wordmark', 'team_conference_logo', 'team_league_logo', 'team_logo_squared']
#
# TEAM SAMPLE:
#    team_abbr              team_name  team_id   team_nick team_conf  \
# 0        ARI      Arizona Cardinals     3800   Cardinals       NFC
# 1        ATL        Atlanta Falcons      200     Falcons       NFC
# 2        BAL       Baltimore Ravens      325      Ravens       AFC
# 3        BUF          Buffalo Bills      610       Bills       AFC
# 4        CAR      Carolina Panthers      750    Panthers       NFC
# 5        CHI          Chicago Bears      810       Bears       NFC
# 6        CIN     Cincinnati Bengals      920     Bengals       AFC
# 7        CLE       Cleveland Browns     1050      Browns       AFC
# 8        DAL         Dallas Cowboys     1200     Cowboys       NFC
# 9        DEN         Denver Broncos     1400     Broncos       AFC
# 10       DET          Detroit Lions     1540       Lions       NFC
# 11        GB      Green Bay Packers     1800     Packers       NFC
# 12       HOU         Houston Texans     2120      Texans       AFC
# 13       IND     Indianapolis Colts     2200       Colts       AFC
# 14       JAX   Jacksonville Jaguars     2250     Jaguars       AFC
# 15        KC     Kansas City Chiefs     2310      Chiefs       AFC
# 16        LA       Los Angeles Rams     2510        Rams       NFC
# 17       LAC   Los Angeles Chargers     4400    Chargers       AFC
# 18       LAR       Los Angeles Rams     2510        Rams       NFC
# 19        LV      Las Vegas Raiders     2520     Raiders       AFC
# 20       MIA         Miami Dolphins     2700    Dolphins       AFC
# 21       MIN      Minnesota Vikings     3000     Vikings       NFC
# 22        NE   New England Patriots     3200    Patriots       AFC
# 23        NO     New Orleans Saints     3300      Saints       NFC
# 24       NYG        New York Giants     3410      Giants       NFC
# 25       NYJ          New York Jets     3430        Jets       AFC
# 26       OAK        Oakland Raiders     2520     Raiders       AFC
# 27       PHI    Philadelphia Eagles     3700      Eagles       NFC
# 28       PIT    Pittsburgh Steelers     3900    Steelers       AFC
# 29        SD     San Diego Chargers     4400    Chargers       AFC
# 30       SEA       Seattle Seahawks     4600    Seahawks       NFC
# 31        SF    San Francisco 49ers     4500       49ers       NFC
# 32       STL         St. Louis Rams     2510        Rams       NFC
# 33        TB   Tampa Bay Buccaneers     4900  Buccaneers       NFC
# 34       TEN       Tennessee Titans     2100      Titans       AFC
# 35       WAS  Washington Commanders     5110  Commanders       NFC
#
#    team_division team_color team_color2 team_color3 team_color4  \
# 0       NFC West    #97233F     #000000     #ffb612     #a5acaf
# 1      NFC South    #A71930     #000000     #a5acaf     #a30d2d
# 2      AFC North    #241773     #9E7C0C     #9e7c0c     #c60c30
# 3       AFC East    #00338D     #C60C30     #0c2e82     #d50a0a
# 4      NFC South    #0085CA     #000000     #bfc0bf     #0085ca
# 5      NFC North    #0B162A     #E64100     #0b162a     #E64100
# 6      AFC North    #FB4F14     #000000     #000000     #d32f1e
# 7      AFC North    #FF3C00     #311D00     #a5acaf     #d32f1e
# 8       NFC East    #002244     #B0B7BC     #acc0c6     #a5acaf
# 9       AFC West    #002244     #FB4F14     #00234c     #ff5200
# 10     NFC North    #0076B6     #B0B7BC     #000000     #004e89
# 11     NFC North    #203731     #FFB612     #1c2d25     #eead1e
# 12     AFC South    #03202F     #A71930     #00071c     #a30d2d
# 13     AFC South    #002C5F     #a5acaf     #013369     #9ba1a2
# 14     AFC South    #006778     #000000     #9f792c     #d7a22a
# 15      AFC West    #E31837     #FFB612     #000000     #e31837
# 16      NFC West    #003594     #FFD100     #001532     #af925d
# 17      AFC West    #007BC7     #ffc20e     #ffb612     #001532
# 18      NFC West    #003594     #FFD100     #001532     #af925d
# 19      AFC West    #000000     #A5ACAF     #a6aeb0     #000000
# 20      AFC East    #008E97     #F58220     #005778     #008e97
# 21     NFC North    #4F2683     #FFC62F     #e9bf9b     #000000
# 22      AFC East    #002244     #C60C30     #b0b7bc     #001532
# 23     NFC South    #D3BC8D     #000000     #9f8958     #000000
# 24      NFC East    #0B2265     #A71930     #a5acaf     #012352
# 25      AFC East    #003F2D     #000000        None        None
# 26      AFC West    #000000     #A5ACAF     #a6aeb0     #000000
# 27      NFC East    #004C54     #A5ACAF     #acc0c6     #000000
# 28     AFC North    #000000     #FFB612     #c60c30     #00539b
# 29      AFC West    #007BC7     #ffc20e     #ffb612     #001532
# 30      NFC West    #002244     #69be28     #a5acaf     #001532
# 31      NFC West    #AA0000     #B3995D     #000000     #a5acaf
# 32      NFC West    #003594     #FFD100     #001532     #af925d
# 33     NFC South    #A71930     #322F2B     #000000     #ff7900
# 34     AFC South    #002244     #4B92DB     #c60c30     #a5acaf
# 35      NFC East    #5A1414     #FFB612     #000000     #5b2b2f
#
#                                   team_logo_wikipedia  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 1   https://upload.wikimedia.org/wikipedia/en/thum...
# 2   https://upload.wikimedia.org/wikipedia/en/thum...
# 3   https://upload.wikimedia.org/wikipedia/en/thum...
# 4   https://upload.wikimedia.org/wikipedia/en/thum...
# 5   https://upload.wikimedia.org/wikipedia/commons...
# 6   https://upload.wikimedia.org/wikipedia/commons...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/commons...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/commons...
# 12  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/commons...
# 14  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/thum...
# 16  https://upload.wikimedia.org/wikipedia/en/thum...
# 17  https://upload.wikimedia.org/wikipedia/en/thum...
# 18  https://upload.wikimedia.org/wikipedia/en/thum...
# 19  https://upload.wikimedia.org/wikipedia/en/thum...
# 20  https://upload.wikimedia.org/wikipedia/en/thum...
# 21  https://upload.wikimedia.org/wikipedia/en/thum...
# 22  https://upload.wikimedia.org/wikipedia/en/thum...
# 23  https://upload.wikimedia.org/wikipedia/commons...
# 24  https://upload.wikimedia.org/wikipedia/commons...
# 25  https://upload.wikimedia.org/wikipedia/en/thum...
# 26  https://upload.wikimedia.org/wikipedia/en/thum...
# 27  https://upload.wikimedia.org/wikipedia/en/thum...
# 28  https://upload.wikimedia.org/wikipedia/commons...
# 29  https://upload.wikimedia.org/wikipedia/en/thum...
# 30  https://upload.wikimedia.org/wikipedia/en/thum...
# 31  https://upload.wikimedia.org/wikipedia/commons...
# 32  https://upload.wikimedia.org/wikipedia/en/thum...
# 33  https://upload.wikimedia.org/wikipedia/en/thum...
# 34  https://github.com/nflverse/nflverse-pbp/raw/m...
# 35  https://upload.wikimedia.org/wikipedia/commons...
#
#                                        team_logo_espn  \
# 0   https://a.espncdn.com/i/teamlogos/nfl/500/ari.png
# 1   https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 2   https://a.espncdn.com/i/teamlogos/nfl/500/bal.png
# 3   https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 4   https://a.espncdn.com/i/teamlogos/nfl/500-dark...
# 5   https://a.espncdn.com/i/teamlogos/nfl/500/chi.png
# 6   https://a.espncdn.com/i/teamlogos/nfl/500/cin.png
# 7   https://a.espncdn.com/i/teamlogos/nfl/500/cle.png
# 8   https://a.espncdn.com/i/teamlogos/nfl/500/dal.png
# 9   https://a.espncdn.com/i/teamlogos/nfl/500/den.png
# 10  https://a.espncdn.com/i/teamlogos/nfl/500/det.png
# 11   https://a.espncdn.com/i/teamlogos/nfl/500/gb.png
# 12  https://a.espncdn.com/i/teamlogos/nfl/500/hou.png
# 13  https://a.espncdn.com/i/teamlogos/nfl/500/ind.png
# 14  https://a.espncdn.com/i/teamlogos/nfl/500/jax.png
# 15   https://a.espncdn.com/i/teamlogos/nfl/500/kc.png
# 16  https://a.espncdn.com/i/teamlogos/nfl/500/lar.png
# 17  https://a.espncdn.com/i/teamlogos/nfl/500/lac.png
# 18  https://a.espncdn.com/i/teamlogos/nfl/500/lar.png
# 19   https://a.espncdn.com/i/teamlogos/nfl/500/lv.png
# 20  https://a.espncdn.com/i/teamlogos/nfl/500/mia.png
# 21  https://a.espncdn.com/i/teamlogos/nfl/500/min.png
# 22   https://a.espncdn.com/i/teamlogos/nfl/500/ne.png
# 23   https://a.espncdn.com/i/teamlogos/nfl/500/no.png
# 24  https://a.espncdn.com/i/teamlogos/nfl/500/nyg.png
# 25  https://a.espncdn.com/i/teamlogos/nfl/500/nyj.png
# 26   https://a.espncdn.com/i/teamlogos/nfl/500/lv.png
# 27  https://a.espncdn.com/i/teamlogos/nfl/500/phi.png
# 28  https://a.espncdn.com/i/teamlogos/nfl/500/pit.png
# 29  https://a.espncdn.com/i/teamlogos/nfl/500/lac.png
# 30  https://a.espncdn.com/i/teamlogos/nfl/500/sea.png
# 31   https://a.espncdn.com/i/teamlogos/nfl/500/sf.png
# 32  https://a.espncdn.com/i/teamlogos/nfl/500/lar.png
# 33   https://a.espncdn.com/i/teamlogos/nfl/500/tb.png
# 34  https://a.espncdn.com/i/teamlogos/nfl/500/ten.png
# 35  https://a.espncdn.com/i/teamlogos/nfl/500/wsh.png
#
#                                         team_wordmark  \
# 0   https://github.com/nflverse/nflverse-pbp/raw/m...
# 1   https://github.com/nflverse/nflverse-pbp/raw/m...
# 2   https://github.com/nflverse/nflverse-pbp/raw/m...
# 3   https://github.com/nflverse/nflverse-pbp/raw/m...
# 4   https://github.com/nflverse/nflverse-pbp/raw/m...
# 5   https://github.com/nflverse/nflverse-pbp/raw/m...
# 6   https://github.com/nflverse/nflverse-pbp/raw/m...
# 7   https://github.com/nflverse/nflverse-pbp/raw/m...
# 8   https://github.com/nflverse/nflverse-pbp/raw/m...
# 9   https://github.com/nflverse/nflverse-pbp/raw/m...
# 10  https://github.com/nflverse/nflverse-pbp/raw/m...
# 11  https://github.com/nflverse/nflverse-pbp/raw/m...
# 12  https://github.com/nflverse/nflverse-pbp/raw/m...
# 13  https://github.com/nflverse/nflverse-pbp/raw/m...
# 14  https://github.com/nflverse/nflverse-pbp/raw/m...
# 15  https://github.com/nflverse/nflverse-pbp/raw/m...
# 16  https://github.com/nflverse/nflverse-pbp/raw/m...
# 17  https://github.com/nflverse/nflverse-pbp/raw/m...
# 18  https://github.com/nflverse/nflverse-pbp/raw/m...
# 19  https://github.com/nflverse/nflverse-pbp/raw/m...
# 20  https://github.com/nflverse/nflverse-pbp/raw/m...
# 21  https://github.com/nflverse/nflverse-pbp/raw/m...
# 22  https://github.com/nflverse/nflverse-pbp/raw/m...
# 23  https://github.com/nflverse/nflverse-pbp/raw/m...
# 24  https://github.com/nflverse/nflverse-pbp/raw/m...
# 25  https://github.com/nflverse/nflverse-pbp/raw/m...
# 26  https://github.com/nflverse/nflverse-pbp/raw/m...
# 27  https://github.com/nflverse/nflverse-pbp/raw/m...
# 28  https://github.com/nflverse/nflverse-pbp/raw/m...
# 29  https://github.com/nflverse/nflverse-pbp/raw/m...
# 30  https://github.com/nflverse/nflverse-pbp/raw/m...
# 31  https://github.com/nflverse/nflverse-pbp/raw/m...
# 32  https://github.com/nflverse/nflverse-pbp/raw/m...
# 33  https://github.com/nflverse/nflverse-pbp/raw/m...
# 34  https://github.com/nflverse/nflverse-pbp/raw/m...
# 35  https://github.com/nflverse/nflverse-pbp/raw/m...
#
#                                  team_conference_logo  \
# 0   https://github.com/nflverse/nflverse-pbp/raw/m...
# 1   https://github.com/nflverse/nflverse-pbp/raw/m...
# 2   https://github.com/nflverse/nflverse-pbp/raw/m...
# 3   https://github.com/nflverse/nflverse-pbp/raw/m...
# 4   https://github.com/nflverse/nflverse-pbp/raw/m...
# 5   https://github.com/nflverse/nflverse-pbp/raw/m...
# 6   https://github.com/nflverse/nflverse-pbp/raw/m...
# 7   https://github.com/nflverse/nflverse-pbp/raw/m...
# 8   https://github.com/nflverse/nflverse-pbp/raw/m...
# 9   https://github.com/nflverse/nflverse-pbp/raw/m...
# 10  https://github.com/nflverse/nflverse-pbp/raw/m...
# 11  https://github.com/nflverse/nflverse-pbp/raw/m...
# 12  https://github.com/nflverse/nflverse-pbp/raw/m...
# 13  https://github.com/nflverse/nflverse-pbp/raw/m...
# 14  https://github.com/nflverse/nflverse-pbp/raw/m...
# 15  https://github.com/nflverse/nflverse-pbp/raw/m...
# 16  https://github.com/nflverse/nflverse-pbp/raw/m...
# 17  https://github.com/nflverse/nflverse-pbp/raw/m...
# 18  https://github.com/nflverse/nflverse-pbp/raw/m...
# 19  https://github.com/nflverse/nflverse-pbp/raw/m...
# 20  https://github.com/nflverse/nflverse-pbp/raw/m...
# 21  https://github.com/nflverse/nflverse-pbp/raw/m...
# 22  https://github.com/nflverse/nflverse-pbp/raw/m...
# 23  https://github.com/nflverse/nflverse-pbp/raw/m...
# 24  https://github.com/nflverse/nflverse-pbp/raw/m...
# 25  https://github.com/nflverse/nflverse-pbp/raw/m...
# 26  https://github.com/nflverse/nflverse-pbp/raw/m...
# 27  https://github.com/nflverse/nflverse-pbp/raw/m...
# 28  https://github.com/nflverse/nflverse-pbp/raw/m...
# 29  https://github.com/nflverse/nflverse-pbp/raw/m...
# 30  https://github.com/nflverse/nflverse-pbp/raw/m...
# 31  https://github.com/nflverse/nflverse-pbp/raw/m...
# 32  https://github.com/nflverse/nflverse-pbp/raw/m...
# 33  https://github.com/nflverse/nflverse-pbp/raw/m...
# 34  https://github.com/nflverse/nflverse-pbp/raw/m...
# 35  https://github.com/nflverse/nflverse-pbp/raw/m...
#
#                                      team_league_logo  \
# 0   https://raw.githubusercontent.com/nflverse/nfl...
# 1   https://raw.githubusercontent.com/nflverse/nfl...
# 2   https://raw.githubusercontent.com/nflverse/nfl...
# 3   https://raw.githubusercontent.com/nflverse/nfl...
# 4   https://raw.githubusercontent.com/nflverse/nfl...
# 5   https://raw.githubusercontent.com/nflverse/nfl...
# 6   https://raw.githubusercontent.com/nflverse/nfl...
# 7   https://raw.githubusercontent.com/nflverse/nfl...
# 8   https://raw.githubusercontent.com/nflverse/nfl...
# 9   https://raw.githubusercontent.com/nflverse/nfl...
# 10  https://raw.githubusercontent.com/nflverse/nfl...
# 11  https://raw.githubusercontent.com/nflverse/nfl...
# 12  https://raw.githubusercontent.com/nflverse/nfl...
# 13  https://raw.githubusercontent.com/nflverse/nfl...
# 14  https://raw.githubusercontent.com/nflverse/nfl...
# 15  https://raw.githubusercontent.com/nflverse/nfl...
# 16  https://raw.githubusercontent.com/nflverse/nfl...
# 17  https://raw.githubusercontent.com/nflverse/nfl...
# 18  https://raw.githubusercontent.com/nflverse/nfl...
# 19  https://raw.githubusercontent.com/nflverse/nfl...
# 20  https://raw.githubusercontent.com/nflverse/nfl...
# 21  https://raw.githubusercontent.com/nflverse/nfl...
# 22  https://raw.githubusercontent.com/nflverse/nfl...
# 23  https://raw.githubusercontent.com/nflverse/nfl...
# 24  https://raw.githubusercontent.com/nflverse/nfl...
# 25  https://raw.githubusercontent.com/nflverse/nfl...
# 26  https://raw.githubusercontent.com/nflverse/nfl...
# 27  https://raw.githubusercontent.com/nflverse/nfl...
# 28  https://raw.githubusercontent.com/nflverse/nfl...
# 29  https://raw.githubusercontent.com/nflverse/nfl...
# 30  https://raw.githubusercontent.com/nflverse/nfl...
# 31  https://raw.githubusercontent.com/nflverse/nfl...
# 32  https://raw.githubusercontent.com/nflverse/nfl...
# 33  https://raw.githubusercontent.com/nflverse/nfl...
# 34  https://raw.githubusercontent.com/nflverse/nfl...
# 35  https://raw.githubusercontent.com/nflverse/nfl...
#
#                                     team_logo_squared
# 0   https://github.com/nflverse/nflverse-pbp/raw/m...
# 1   https://github.com/nflverse/nflverse-pbp/raw/m...
# 2   https://github.com/nflverse/nflverse-pbp/raw/m...
# 3   https://github.com/nflverse/nflverse-pbp/raw/m...
# 4   https://github.com/nflverse/nflverse-pbp/raw/m...
# 5   https://github.com/nflverse/nflverse-pbp/raw/m...
# 6   https://github.com/nflverse/nflverse-pbp/raw/m...
# 7   https://github.com/nflverse/nflverse-pbp/raw/m...
# 8   https://github.com/nflverse/nflverse-pbp/raw/m...
# 9   https://github.com/nflverse/nflverse-pbp/raw/m...
# 10  https://github.com/nflverse/nflverse-pbp/raw/m...
# 11  https://github.com/nflverse/nflverse-pbp/raw/m...
# 12  https://github.com/nflverse/nflverse-pbp/raw/m...
# 13  https://github.com/nflverse/nflverse-pbp/raw/m...
# 14  https://github.com/nflverse/nflverse-pbp/raw/m...
# 15  https://github.com/nflverse/nflverse-pbp/raw/m...
# 16  https://github.com/nflverse/nflverse-pbp/raw/m...
# 17  https://github.com/nflverse/nflverse-pbp/raw/m...
# 18  https://github.com/nflverse/nflverse-pbp/raw/m...
# 19  https://github.com/nflverse/nflverse-pbp/raw/m...
# 20  https://github.com/nflverse/nflverse-pbp/raw/m...
# 21  https://github.com/nflverse/nflverse-pbp/raw/m...
# 22  https://github.com/nflverse/nflverse-pbp/raw/m...
# 23  https://github.com/nflverse/nflverse-pbp/raw/m...
# 24  https://github.com/nflverse/nflverse-pbp/raw/m...
# 25  https://github.com/nflverse/nflverse-pbp/raw/m...
# 26  https://github.com/nflverse/nflverse-pbp/raw/m...
# 27  https://github.com/nflverse/nflverse-pbp/raw/m...
# 28  https://github.com/nflverse/nflverse-pbp/raw/m...
# 29  https://github.com/nflverse/nflverse-pbp/raw/m...
# 30  https://github.com/nflverse/nflverse-pbp/raw/m...
# 31  https://github.com/nflverse/nflverse-pbp/raw/m...
# 32  https://github.com/nflverse/nflverse-pbp/raw/m...
# 33  https://github.com/nflverse/nflverse-pbp/raw/m...
# 34  https://github.com/nflverse/nflverse-pbp/raw/m...
# 35  https://github.com/nflverse/nflverse-pbp/raw/m...

# %%
def build_real_season_dfs(year: int):
    # Load in the schedules
    sch = nfl.load_schedules([year]).to_pandas()

    # Keep all regular season games
    sch = sch[(sch["season"] == year) & (sch["game_type"] == "REG")].copy()

    # Load in NFL Team Data, need to convert to pandas cause the nflreadpy is weird
    teams = nfl.load_teams().to_pandas()

    # Connect the NFL Team Data to the abbreviations in the schedule section
    team_cols = ["team_abbr", "team_name", "team_conf", "team_division"]

    # Do a left join for all home teams in the results
    sch = sch.merge(teams[team_cols],left_on="home_team",right_on="team_abbr").rename(columns={ "team_name": "Home",
        "team_conf": "Home_Conf", "team_division": "Home_Div"
        }).drop(columns=["team_abbr"])

    # Do a left join for all the away teams in the results
    sch = sch.merge(teams[team_cols],left_on="away_team",right_on="team_abbr").rename(columns={"team_name": "Away",
        "team_conf": "Away_Conf","team_division": "Away_Div"
        }).drop(columns=["team_abbr"])
  
    # Keep track of the margins for every game
    home_score = sch["home_score"]
    away_score = sch["away_score"]
    margin_home = home_score - away_score

    # Create an empty pandas series to store each game's winner and loser
    winner = pd.Series([None] * len(sch), index=sch.index)
    loser  = pd.Series([None] * len(sch), index=sch.index)

    # home wins if margin > 0, away wins if less than 0
    home_win = margin_home > 0
    away_win = margin_home < 0

    # Attach winners and losers based on the boolean function into the winner and lsoer series
    winner[home_win] = sch.loc[home_win, "Home"]
    loser[home_win]  = sch.loc[home_win, "Away"]  
    winner[away_win] = sch.loc[away_win, "Away"]
    loser[away_win]  = sch.loc[away_win, "Home"]
 
    # Create the results dataframe, exactly in the format I created my results in for the simulations
    results_df = pd.DataFrame({"Home": sch["Home"],"Away": sch["Away"],"Winner": winner,
        "Loser": loser, "Divisional": sch["Home_Div"] == sch["Away_Div"],
        "Conference": sch["Home_Conf"] == sch["Away_Conf"], "Margin": margin_home,
        "Home_Score": home_score, "Away_Score": away_score,
    })

    #group teams by amount of wins
    wins = results_df["Winner"].value_counts()
    losses = results_df["Loser"].value_counts()
  
    # map teams wins and losses to the standings
    standings = pd.DataFrame({"Team": teams["team_name"].unique()})
    standings["Wins"] = standings["Team"].map(wins).fillna(0).astype(int)
    standings["Losses"] = standings["Team"].map(losses).fillna(0).astype(int)

    div_wins = results_df.loc[results_df["Divisional"], "Winner"].value_counts()
    conf_wins = results_df.loc[results_df["Conference"], "Winner"].value_counts()
    # map teams divisional and conference wins
    standings["Div_Wins"] = standings["Team"].map(div_wins).fillna(0).astype(int)
    standings["Conf_Wins"] = standings["Team"].map(conf_wins).fillna(0).astype(int)

    # map all teams to correct conference and division
    team_info = teams.set_index("team_name")[["team_conf", "team_division"]]
    standings["Conference"] = standings["Team"].map(team_info["team_conf"].to_dict())
    standings["Division"] = standings["Team"].map(team_info["team_division"].to_dict())

    # cummulative margin for home and away teams grouped by team
    home_margin = (results_df["Home_Score"] - results_df["Away_Score"]).groupby(results_df["Home"]).sum()
    away_margin = (results_df["Away_Score"] - results_df["Home_Score"]).groupby(results_df["Away"]).sum()

    # merge them together
    total_margin = home_margin.add(away_margin, fill_value=0)
    standings["Total_Margin"] = standings["Team"].map(total_margin).fillna(0).astype(int)
   
    # remove teams with no wins/losses (ie, Oakland Raiders)
    standings = standings[~((standings["Wins"] == 0) & (standings["Losses"] == 0))]
 
    # Sort the standings by wins and total margin
    standings_df = standings.sort_values(["Wins", "Total_Margin"], ascending=[False, False]).reset_index(drop=True)
    return results_df, standings_df

# %%
total = Counter()

# Loop through the years and count the # of tiebreakers
for year in range(2002, 2026):
    results_df, standings_df = build_real_season_dfs(year)
    field, tbs = playoff_field(standings_df, results_df)
    total.update(tbs)
    print(year, "Playoff field")
    print(field)
    print(standings_df)

print(total)
#print(standings_df)
#print(results_df)
# Out:
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2002 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1       Oakland Raiders   AFC West    11       5
# 1         AFC     2      Tennessee Titans  AFC South    11       5
# 2         AFC     3   Pittsburgh Steelers  AFC North    10       5
# 3         AFC     4         New York Jets   AFC East     9       7
# 4         AFC     5    Indianapolis Colts  AFC South    10       6
# 5         AFC     6      Cleveland Browns  AFC North     9       7
# 6         AFC     7  New England Patriots   AFC East     9       7
# 7         NFC     1   Philadelphia Eagles   NFC East    12       4
# 8         NFC     2  Tampa Bay Buccaneers  NFC South    12       4
# 9         NFC     3     Green Bay Packers  NFC North    12       4
# 10        NFC     4   San Francisco 49ers   NFC West    10       6
# 11        NFC     5       New York Giants   NFC East    10       6
# 12        NFC     6       Atlanta Falcons  NFC South     9       6
# 13        NFC     7    New Orleans Saints  NFC South     9       7
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0     Philadelphia Eagles    12       4         5         11        NFC
# 1    Tampa Bay Buccaneers    12       4         4          9        NFC
# 2       Green Bay Packers    12       4         5          9        NFC
# 3         Oakland Raiders    11       5         4          9        AFC
# 4        Tennessee Titans    11       5         6          9        AFC
# 5     Pittsburgh Steelers    10       5         6          8        AFC
# 6         New York Giants    10       6         5          8        NFC
# 7      Indianapolis Colts    10       6         4          8        AFC
# 8     San Francisco 49ers    10       6         5          8        NFC
# 9         Atlanta Falcons     9       6         4          7        NFC
# 10         Miami Dolphins     9       7         2          7        AFC
# 11         Denver Broncos     9       7         3          5        AFC
# 12     New Orleans Saints     9       7         3          7        NFC
# 13   New England Patriots     9       7         4          6        AFC
# 14       Cleveland Browns     9       7         3          7        AFC
# 15          New York Jets     9       7         4          6        AFC
# 16     Kansas City Chiefs     8       8         2          6        AFC
# 17          Buffalo Bills     8       8         2          5        AFC
# 18     San Diego Chargers     8       8         3          6        AFC
# 19       Seattle Seahawks     7       9         2          5        NFC
# 20       Baltimore Ravens     7       9         3          7        AFC
# 21      Carolina Panthers     7       9         1          4        NFC
# 22         St. Louis Rams     7       9         4          5        NFC
# 23  Washington Commanders     7       9         1          4        NFC
# 24   Jacksonville Jaguars     6      10         1          4        AFC
# 25      Minnesota Vikings     6      10         4          5        NFC
# 26         Dallas Cowboys     5      11         1          3        NFC
# 27      Arizona Cardinals     5      11         1          5        NFC
# 28          Chicago Bears     4      12         2          3        NFC
# 29         Houston Texans     4      12         1          2        AFC
# 30          Detroit Lions     3      13         1          3        NFC
# 31     Cincinnati Bengals     2      14         0          1        AFC
#
#      Division  Total_Margin
# 0    NFC East           174
# 1   NFC South           150
# 2   NFC North            70
# 3    AFC West           146
# 4   AFC South            43
# 5   AFC North            45
# 6    NFC East            41
# 7   AFC South            36
# 8    NFC West            16
# 9   NFC South            88
# 10   AFC East            77
# 11   AFC West            48
# 12  NFC South            44
# 13   AFC East            35
# 14  AFC North            24
# 15   AFC East            23
# 16   AFC West            68
# 17   AFC East           -18
# 18   AFC West           -34
# 19   NFC West           -14
# 20  AFC North           -38
# 21  NFC South           -44
# 22   NFC West           -53
# 23   NFC East           -58
# 24  AFC South            13
# 25  NFC North           -52
# 26   NFC East          -112
# 27   NFC West          -155
# 28  NFC North           -98
# 29  AFC South          -143
# 30  NFC North          -145
# 31  AFC North          -177
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2003 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1  New England Patriots   AFC East    14       2
# 1         AFC     2    Kansas City Chiefs   AFC West    13       3
# 2         AFC     3    Indianapolis Colts  AFC South    12       4
# 3         AFC     4      Baltimore Ravens  AFC North    10       6
# 4         AFC     5      Tennessee Titans  AFC South    12       4
# 5         AFC     6        Denver Broncos   AFC West    10       6
# 6         AFC     7        Miami Dolphins   AFC East    10       6
# 7         NFC     1   Philadelphia Eagles   NFC East    12       4
# 8         NFC     2        St. Louis Rams   NFC West    12       4
# 9         NFC     3     Carolina Panthers  NFC South    11       5
# 10        NFC     4     Green Bay Packers  NFC North    10       6
# 11        NFC     5      Seattle Seahawks   NFC West    10       6
# 12        NFC     6        Dallas Cowboys   NFC East    10       6
# 13        NFC     7     Minnesota Vikings  NFC North     9       7
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0    New England Patriots    14       2         5         11        AFC
# 1      Kansas City Chiefs    13       3         5         10        AFC
# 2          St. Louis Rams    12       4         4          8        NFC
# 3      Indianapolis Colts    12       4         5          9        AFC
# 4        Tennessee Titans    12       4         4          8        AFC
# 5     Philadelphia Eagles    12       4         5          9        NFC
# 6       Carolina Panthers    11       5         5          9        NFC
# 7       Green Bay Packers    10       6         4          7        NFC
# 8        Baltimore Ravens    10       6         4          7        AFC
# 9          Denver Broncos    10       6         5          9        AFC
# 10       Seattle Seahawks    10       6         5          8        NFC
# 11         Miami Dolphins    10       6         4          7        AFC
# 12         Dallas Cowboys    10       6         5          8        NFC
# 13      Minnesota Vikings     9       7         4          7        NFC
# 14     New Orleans Saints     8       8         3          7        NFC
# 15     Cincinnati Bengals     8       8         3          6        AFC
# 16    San Francisco 49ers     7       9         2          6        NFC
# 17   Tampa Bay Buccaneers     7       9         2          6        NFC
# 18          Chicago Bears     7       9         2          4        NFC
# 19          New York Jets     6      10         1          6        AFC
# 20    Pittsburgh Steelers     6      10         3          5        AFC
# 21          Buffalo Bills     6      10         2          4        AFC
# 22   Jacksonville Jaguars     5      11         2          3        AFC
# 23       Cleveland Browns     5      11         2          3        AFC
# 24  Washington Commanders     5      11         1          3        NFC
# 25          Detroit Lions     5      11         2          4        NFC
# 26        Atlanta Falcons     5      11         2          4        NFC
# 27         Houston Texans     5      11         1          3        AFC
# 28        Oakland Raiders     4      12         1          3        AFC
# 29     San Diego Chargers     4      12         1          2        AFC
# 30        New York Giants     4      12         1          3        NFC
# 31      Arizona Cardinals     4      12         1          3        NFC
#
#      Division  Total_Margin
# 0    AFC East           110
# 1    AFC West           152
# 2    NFC West           119
# 3   AFC South           111
# 4   AFC South           111
# 5    NFC East            87
# 6   NFC South            21
# 7   NFC North           135
# 8   AFC North           110
# 9    AFC West            80
# 10   NFC West            77
# 11   AFC East            50
# 12   NFC East            29
# 13  NFC North            63
# 14  NFC South            14
# 15  AFC North           -38
# 16   NFC West            47
# 17  NFC South            37
# 18  NFC North           -63
# 19   AFC East           -16
# 20  AFC North           -27
# 21   AFC East           -36
# 22  AFC South           -55
# 23  AFC North           -68
# 24   NFC East           -85
# 25  NFC North          -109
# 26  NFC South          -123
# 27  AFC South          -125
# 28   AFC West          -109
# 29   AFC West          -128
# 30   NFC East          -144
# 31   NFC West          -227
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2004 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1   Pittsburgh Steelers  AFC North    15       1
# 1         AFC     2  New England Patriots   AFC East    14       2
# 2         AFC     3    Indianapolis Colts  AFC South    12       4
# 3         AFC     4    San Diego Chargers   AFC West    12       4
# 4         AFC     5         New York Jets   AFC East    10       6
# 5         AFC     6        Denver Broncos   AFC West    10       6
# 6         AFC     7  Jacksonville Jaguars  AFC South     9       7
# 7         NFC     1   Philadelphia Eagles   NFC East    13       3
# 8         NFC     2       Atlanta Falcons  NFC South    11       5
# 9         NFC     3     Green Bay Packers  NFC North    10       6
# 10        NFC     4      Seattle Seahawks   NFC West     9       7
# 11        NFC     5        St. Louis Rams   NFC West     8       8
# 12        NFC     6     Minnesota Vikings  NFC North     8       8
# 13        NFC     7    New Orleans Saints  NFC South     8       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0     Pittsburgh Steelers    15       1         5         11        AFC
# 1    New England Patriots    14       2         5         10        AFC
# 2     Philadelphia Eagles    13       3         6         11        NFC
# 3      Indianapolis Colts    12       4         5          8        AFC
# 4      San Diego Chargers    12       4         5          9        AFC
# 5         Atlanta Falcons    11       5         4          8        NFC
# 6          Denver Broncos    10       6         3          7        AFC
# 7           New York Jets    10       6         3          7        AFC
# 8       Green Bay Packers    10       6         5          9        NFC
# 9           Buffalo Bills     9       7         3          5        AFC
# 10       Baltimore Ravens     9       7         3          6        AFC
# 11       Seattle Seahawks     9       7         3          8        NFC
# 12   Jacksonville Jaguars     9       7         2          6        AFC
# 13      Minnesota Vikings     8       8         3          5        NFC
# 14     Cincinnati Bengals     8       8         2          4        AFC
# 15     New Orleans Saints     8       8         3          6        NFC
# 16         St. Louis Rams     8       8         5          7        NFC
# 17     Kansas City Chiefs     7       9         3          6        AFC
# 18      Carolina Panthers     7       9         3          6        NFC
# 19         Houston Texans     7       9         4          6        AFC
# 20  Washington Commanders     6      10         1          6        NFC
# 21      Arizona Cardinals     6      10         2          5        NFC
# 22        New York Giants     6      10         3          5        NFC
# 23          Detroit Lions     6      10         2          5        NFC
# 24         Dallas Cowboys     6      10         2          5        NFC
# 25   Tampa Bay Buccaneers     5      11         2          4        NFC
# 26       Tennessee Titans     5      11         1          3        AFC
# 27          Chicago Bears     5      11         2          4        NFC
# 28        Oakland Raiders     5      11         1          3        AFC
# 29         Miami Dolphins     4      12         1          2        AFC
# 30       Cleveland Browns     4      12         2          3        AFC
# 31    San Francisco 49ers     2      14         2          2        NFC
#
#      Division  Total_Margin
# 0   AFC North           121
# 1    AFC East           177
# 2    NFC East           126
# 3   AFC South           171
# 4    AFC West           133
# 5   NFC South             3
# 6    AFC West            77
# 7    AFC East            72
# 8   NFC North            44
# 9    AFC East           111
# 10  AFC North            49
# 11   NFC West            -2
# 12  AFC South           -19
# 13  NFC North            10
# 14  AFC North             2
# 15  NFC South           -57
# 16   NFC West           -73
# 17   AFC West            48
# 18  NFC South            16
# 19  AFC South           -30
# 20   NFC East           -25
# 21   NFC West           -38
# 22   NFC East           -44
# 23  NFC North           -54
# 24   NFC East          -112
# 25  NFC South            -3
# 26  AFC South           -95
# 27  NFC North          -100
# 28   AFC West          -122
# 29   AFC East           -79
# 30  AFC North          -114
# 31   NFC West          -193
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2005 Playoff field
#    Conference  Seed                   Team   Division  Wins  Losses
# 0         AFC     1     Indianapolis Colts  AFC South    14       2
# 1         AFC     2         Denver Broncos   AFC West    13       3
# 2         AFC     3     Cincinnati Bengals  AFC North    11       5
# 3         AFC     4   New England Patriots   AFC East    10       6
# 4         AFC     5   Jacksonville Jaguars  AFC South    12       4
# 5         AFC     6    Pittsburgh Steelers  AFC North    11       5
# 6         AFC     7     Kansas City Chiefs   AFC West    10       6
# 7         NFC     1       Seattle Seahawks   NFC West    13       3
# 8         NFC     2          Chicago Bears  NFC North    11       5
# 9         NFC     3   Tampa Bay Buccaneers  NFC South    11       5
# 10        NFC     4        New York Giants   NFC East    11       5
# 11        NFC     5      Carolina Panthers  NFC South    11       5
# 12        NFC     6  Washington Commanders   NFC East    10       6
# 13        NFC     7      Minnesota Vikings  NFC North     9       7
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0      Indianapolis Colts    14       2         6         11        AFC
# 1        Seattle Seahawks    13       3         6         10        NFC
# 2          Denver Broncos    13       3         5         10        AFC
# 3    Jacksonville Jaguars    12       4         4          9        AFC
# 4       Carolina Panthers    11       5         4          8        NFC
# 5     Pittsburgh Steelers    11       5         4          7        AFC
# 6         New York Giants    11       5         4          8        NFC
# 7      Cincinnati Bengals    11       5         5          7        AFC
# 8           Chicago Bears    11       5         5         10        NFC
# 9    Tampa Bay Buccaneers    11       5         5          9        NFC
# 10     Kansas City Chiefs    10       6         4          9        AFC
# 11  Washington Commanders    10       6         5         10        NFC
# 12   New England Patriots    10       6         5          7        AFC
# 13     San Diego Chargers     9       7         3          7        AFC
# 14         Dallas Cowboys     9       7         3          7        NFC
# 15         Miami Dolphins     9       7         3          7        AFC
# 16      Minnesota Vikings     9       7         5          8        NFC
# 17        Atlanta Falcons     8       8         2          5        NFC
# 18       Baltimore Ravens     6      10         2          4        AFC
# 19         St. Louis Rams     6      10         1          3        NFC
# 20       Cleveland Browns     6      10         1          4        AFC
# 21    Philadelphia Eagles     6      10         0          3        NFC
# 22      Arizona Cardinals     5      11         3          4        NFC
# 23          Detroit Lions     5      11         1          3        NFC
# 24          Buffalo Bills     5      11         2          5        AFC
# 25      Green Bay Packers     4      12         1          4        NFC
# 26        Oakland Raiders     4      12         0          2        AFC
# 27          New York Jets     4      12         2          3        AFC
# 28       Tennessee Titans     4      12         2          3        AFC
# 29    San Francisco 49ers     4      12         2          3        NFC
# 30     New Orleans Saints     3      13         1          1        NFC
# 31         Houston Texans     2      14         0          1        AFC
#
#      Division  Total_Margin
# 0   AFC South           192
# 1    NFC West           181
# 2    AFC West           137
# 3   AFC South            92
# 4   NFC South           132
# 5   AFC North           131
# 6    NFC East           108
# 7   AFC North            71
# 8   NFC North            58
# 9   NFC South            26
# 10   AFC West            78
# 11   NFC East            66
# 12   AFC East            41
# 13   AFC West           106
# 14   NFC East            17
# 15   AFC East             1
# 16  NFC North           -38
# 17  NFC South            10
# 18  AFC North           -34
# 19   NFC West           -66
# 20  AFC North           -69
# 21   NFC East           -78
# 22   NFC West           -76
# 23  NFC North           -91
# 24   AFC East           -96
# 25  NFC North           -46
# 26   AFC West           -93
# 27   AFC East          -115
# 28  AFC South          -122
# 29   NFC West          -189
# 30  NFC South          -163
# 31  AFC South          -171
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2006 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1    San Diego Chargers   AFC West    14       2
# 1         AFC     2      Baltimore Ravens  AFC North    13       3
# 2         AFC     3    Indianapolis Colts  AFC South    12       4
# 3         AFC     4  New England Patriots   AFC East    12       4
# 4         AFC     5         New York Jets   AFC East    10       6
# 5         AFC     6    Kansas City Chiefs   AFC West     9       7
# 6         AFC     7        Denver Broncos   AFC West     9       7
# 7         NFC     1         Chicago Bears  NFC North    13       3
# 8         NFC     2    New Orleans Saints  NFC South    10       6
# 9         NFC     3   Philadelphia Eagles   NFC East    10       6
# 10        NFC     4      Seattle Seahawks   NFC West     9       7
# 11        NFC     5        Dallas Cowboys   NFC East     9       7
# 12        NFC     6       New York Giants   NFC East     8       8
# 13        NFC     7     Green Bay Packers  NFC North     8       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0      San Diego Chargers    14       2         5         10        AFC
# 1           Chicago Bears    13       3         5         11        NFC
# 2        Baltimore Ravens    13       3         5         10        AFC
# 3    New England Patriots    12       4         4          8        AFC
# 4      Indianapolis Colts    12       4         3          9        AFC
# 5      New Orleans Saints    10       6         4          9        NFC
# 6     Philadelphia Eagles    10       6         5          9        NFC
# 7           New York Jets    10       6         4          7        AFC
# 8          Dallas Cowboys     9       7         2          6        NFC
# 9      Kansas City Chiefs     9       7         4          5        AFC
# 10         Denver Broncos     9       7         3          8        AFC
# 11       Seattle Seahawks     9       7         3          7        NFC
# 12   Jacksonville Jaguars     8       8         2          5        AFC
# 13     Cincinnati Bengals     8       8         4          6        AFC
# 14    Pittsburgh Steelers     8       8         3          5        AFC
# 15        New York Giants     8       8         4          7        NFC
# 16         St. Louis Rams     8       8         2          6        NFC
# 17      Carolina Panthers     8       8         5          6        NFC
# 18      Green Bay Packers     8       8         5          7        NFC
# 19       Tennessee Titans     8       8         4          5        AFC
# 20          Buffalo Bills     7       9         3          5        AFC
# 21        Atlanta Falcons     7       9         3          5        NFC
# 22    San Francisco 49ers     7       9         3          5        NFC
# 23         Miami Dolphins     6      10         1          3        AFC
# 24      Minnesota Vikings     6      10         2          6        NFC
# 25         Houston Texans     6      10         3          6        AFC
# 26  Washington Commanders     5      11         1          3        NFC
# 27      Arizona Cardinals     5      11         4          5        NFC
# 28       Cleveland Browns     4      12         0          3        AFC
# 29   Tampa Bay Buccaneers     4      12         0          2        NFC
# 30          Detroit Lions     3      13         0          2        NFC
# 31        Oakland Raiders     2      14         0          1        AFC
#
#      Division  Total_Margin
# 0    AFC West           189
# 1   NFC North           172
# 2   AFC North           152
# 3    AFC East           148
# 4   AFC South            67
# 5   NFC South            91
# 6    NFC East            70
# 7    AFC East            21
# 8    NFC East            75
# 9    AFC West            16
# 10   AFC West            14
# 11   NFC West            -6
# 12  AFC South            97
# 13  AFC North            42
# 14  AFC North            38
# 15   NFC East            -7
# 16   NFC West           -14
# 17  NFC South           -35
# 18  NFC North           -65
# 19  AFC South           -76
# 20   AFC East           -11
# 21  NFC South           -36
# 22   NFC West          -114
# 23   AFC East           -23
# 24  NFC North           -45
# 25  AFC South           -99
# 26   NFC East           -69
# 27   NFC West           -75
# 28  AFC North          -118
# 29  NFC South          -142
# 30  NFC North           -93
# 31   AFC West          -164
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2007 Playoff field
#    Conference  Seed                   Team   Division  Wins  Losses
# 0         AFC     1   New England Patriots   AFC East    16       0
# 1         AFC     2     Indianapolis Colts  AFC South    13       3
# 2         AFC     3     San Diego Chargers   AFC West    11       5
# 3         AFC     4    Pittsburgh Steelers  AFC North    10       6
# 4         AFC     5   Jacksonville Jaguars  AFC South    11       5
# 5         AFC     6       Tennessee Titans  AFC South    10       6
# 6         AFC     7       Cleveland Browns  AFC North    10       6
# 7         NFC     1         Dallas Cowboys   NFC East    13       3
# 8         NFC     2      Green Bay Packers  NFC North    13       3
# 9         NFC     3       Seattle Seahawks   NFC West    10       6
# 10        NFC     4   Tampa Bay Buccaneers  NFC South     9       7
# 11        NFC     5        New York Giants   NFC East    10       6
# 12        NFC     6  Washington Commanders   NFC East     9       7
# 13        NFC     7    Philadelphia Eagles   NFC East     8       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0    New England Patriots    16       0         6         12        AFC
# 1      Indianapolis Colts    13       3         5          9        AFC
# 2       Green Bay Packers    13       3         4          9        NFC
# 3          Dallas Cowboys    13       3         4         10        NFC
# 4      San Diego Chargers    11       5         5          9        AFC
# 5    Jacksonville Jaguars    11       5         2          8        AFC
# 6     Pittsburgh Steelers    10       6         5          7        AFC
# 7        Seattle Seahawks    10       6         5          8        NFC
# 8         New York Giants    10       6         3          7        NFC
# 9        Cleveland Browns    10       6         3          7        AFC
# 10       Tennessee Titans    10       6         4          7        AFC
# 11   Tampa Bay Buccaneers     9       7         5          8        NFC
# 12  Washington Commanders     9       7         3          7        NFC
# 13      Minnesota Vikings     8       8         3          6        NFC
# 14    Philadelphia Eagles     8       8         2          5        NFC
# 15      Arizona Cardinals     8       8         3          5        NFC
# 16         Houston Texans     8       8         1          5        AFC
# 17     Cincinnati Bengals     7       9         3          6        AFC
# 18     New Orleans Saints     7       9         3          6        NFC
# 19          Chicago Bears     7       9         2          4        NFC
# 20      Carolina Panthers     7       9         3          7        NFC
# 21         Denver Broncos     7       9         3          6        AFC
# 22          Detroit Lions     7       9         3          4        NFC
# 23          Buffalo Bills     7       9         4          6        AFC
# 24       Baltimore Ravens     5      11         1          2        AFC
# 25    San Francisco 49ers     5      11         3          4        NFC
# 26          New York Jets     4      12         2          4        AFC
# 27     Kansas City Chiefs     4      12         2          3        AFC
# 28        Oakland Raiders     4      12         2          4        AFC
# 29        Atlanta Falcons     4      12         1          3        NFC
# 30         St. Louis Rams     3      13         1          3        NFC
# 31         Miami Dolphins     1      15         0          1        AFC
#
#      Division  Total_Margin
# 0    AFC East           315
# 1   AFC South           188
# 2   NFC North           144
# 3    NFC East           130
# 4    AFC West           128
# 5   AFC South           107
# 6   AFC North           124
# 7    NFC West           102
# 8    NFC East            22
# 9   AFC North            20
# 10  AFC South             4
# 11  NFC South            64
# 12   NFC East            24
# 13  NFC North            54
# 14   NFC East            36
# 15   NFC West             5
# 16  AFC South            -5
# 17  AFC North            -5
# 18  NFC South            -9
# 19  NFC North           -14
# 20  NFC South           -80
# 21   AFC West           -89
# 22  NFC North           -98
# 23   AFC East          -102
# 24  AFC North          -109
# 25   NFC West          -145
# 26   AFC East           -87
# 27   AFC West          -109
# 28   AFC West          -115
# 29  NFC South          -155
# 30   NFC West          -175
# 31   AFC East          -170
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2008 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1      Tennessee Titans  AFC South    13       3
# 1         AFC     2   Pittsburgh Steelers  AFC North    12       4
# 2         AFC     3        Miami Dolphins   AFC East    11       5
# 3         AFC     4    San Diego Chargers   AFC West     8       8
# 4         AFC     5    Indianapolis Colts  AFC South    12       4
# 5         AFC     6      Baltimore Ravens  AFC North    11       5
# 6         AFC     7  New England Patriots   AFC East    11       5
# 7         NFC     1       New York Giants   NFC East    12       4
# 8         NFC     2     Carolina Panthers  NFC South    12       4
# 9         NFC     3     Minnesota Vikings  NFC North    10       6
# 10        NFC     4     Arizona Cardinals   NFC West     9       7
# 11        NFC     5       Atlanta Falcons  NFC South    11       5
# 12        NFC     6        Dallas Cowboys   NFC East     9       7
# 13        NFC     7  Tampa Bay Buccaneers  NFC South     9       7
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0        Tennessee Titans    13       3         4          9        AFC
# 1         New York Giants    12       4         4          9        NFC
# 2     Pittsburgh Steelers    12       4         6         10        AFC
# 3       Carolina Panthers    12       4         4          8        NFC
# 4      Indianapolis Colts    12       4         4         10        AFC
# 5        Baltimore Ravens    11       5         4          8        AFC
# 6    New England Patriots    11       5         4          7        AFC
# 7         Atlanta Falcons    11       5         3          8        NFC
# 8          Miami Dolphins    11       5         4          8        AFC
# 9       Minnesota Vikings    10       6         4          8        NFC
# 10    Philadelphia Eagles     9       6         2          7        NFC
# 11          New York Jets     9       7         4          7        AFC
# 12   Tampa Bay Buccaneers     9       7         3          8        NFC
# 13          Chicago Bears     9       7         4          7        NFC
# 14      Arizona Cardinals     9       7         6          7        NFC
# 15         Dallas Cowboys     9       7         3          7        NFC
# 16     San Diego Chargers     8       8         5          7        AFC
# 17     New Orleans Saints     8       8         2          5        NFC
# 18         Houston Texans     8       8         2          5        AFC
# 19  Washington Commanders     8       8         3          7        NFC
# 20         Denver Broncos     8       8         3          5        AFC
# 21          Buffalo Bills     7       9         0          5        AFC
# 22    San Francisco 49ers     7       9         3          5        NFC
# 23      Green Bay Packers     6      10         4          5        NFC
# 24   Jacksonville Jaguars     5      11         2          3        AFC
# 25        Oakland Raiders     5      11         2          4        AFC
# 26       Seattle Seahawks     4      12         3          3        NFC
# 27       Cleveland Browns     4      12         1          3        AFC
# 28     Cincinnati Bengals     4      11         1          3        AFC
# 29     Kansas City Chiefs     2      14         2          2        AFC
# 30         St. Louis Rams     2      14         0          2        NFC
# 31          Detroit Lions     0      16         0          0        NFC
#
#      Division  Total_Margin
# 0   AFC South           141
# 1    NFC East           133
# 2   AFC North           124
# 3   NFC South            85
# 4   AFC South            79
# 5   AFC North           141
# 6    AFC East           101
# 7   NFC South            66
# 8    AFC East            28
# 9   NFC North            46
# 10   NFC East           127
# 11   AFC East            49
# 12  NFC South            38
# 13  NFC North            25
# 14   NFC West             1
# 15   NFC East            -3
# 16   AFC West            92
# 17  NFC South            70
# 18  AFC South           -28
# 19   NFC East           -31
# 20   AFC West           -78
# 21   AFC East            -6
# 22   NFC West           -42
# 23  NFC North            39
# 24  AFC South           -65
# 25   AFC West          -125
# 26   NFC West           -98
# 27  AFC North          -118
# 28  AFC North          -160
# 29   AFC West          -149
# 30   NFC West          -233
# 31  NFC North          -249
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2009 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1    Indianapolis Colts  AFC South    14       2
# 1         AFC     2    San Diego Chargers   AFC West    13       3
# 2         AFC     3  New England Patriots   AFC East    10       6
# 3         AFC     4    Cincinnati Bengals  AFC North    10       6
# 4         AFC     5         New York Jets   AFC East     9       7
# 5         AFC     6      Baltimore Ravens  AFC North     9       7
# 6         AFC     7        Houston Texans  AFC South     9       7
# 7         NFC     1    New Orleans Saints  NFC South    13       3
# 8         NFC     2     Minnesota Vikings  NFC North    12       4
# 9         NFC     3        Dallas Cowboys   NFC East    11       5
# 10        NFC     4     Arizona Cardinals   NFC West    10       6
# 11        NFC     5     Green Bay Packers  NFC North    11       5
# 12        NFC     6   Philadelphia Eagles   NFC East    11       5
# 13        NFC     7       Atlanta Falcons  NFC South     9       7
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0      Indianapolis Colts    14       2         6         10        AFC
# 1      New Orleans Saints    13       3         4          9        NFC
# 2      San Diego Chargers    13       3         5          9        AFC
# 3       Minnesota Vikings    12       4         5          9        NFC
# 4       Green Bay Packers    11       5         4          9        NFC
# 5          Dallas Cowboys    11       5         4          9        NFC
# 6     Philadelphia Eagles    11       5         4          9        NFC
# 7    New England Patriots    10       6         4          7        AFC
# 8       Arizona Cardinals    10       6         4          8        NFC
# 9      Cincinnati Bengals    10       6         6          7        AFC
# 10       Baltimore Ravens     9       7         3          7        AFC
# 11          New York Jets     9       7         2          7        AFC
# 12         Houston Texans     9       7         1          6        AFC
# 13    Pittsburgh Steelers     9       7         2          6        AFC
# 14        Atlanta Falcons     9       7         3          6        NFC
# 15    San Francisco 49ers     8       8         5          7        NFC
# 16      Carolina Panthers     8       8         4          8        NFC
# 17         Denver Broncos     8       8         3          6        AFC
# 18        New York Giants     8       8         4          6        NFC
# 19       Tennessee Titans     8       8         2          4        AFC
# 20         Miami Dolphins     7       9         4          5        AFC
# 21          Chicago Bears     7       9         3          5        NFC
# 22   Jacksonville Jaguars     7       9         3          6        AFC
# 23          Buffalo Bills     6      10         2          4        AFC
# 24       Seattle Seahawks     5      11         3          4        NFC
# 25       Cleveland Browns     5      11         1          5        AFC
# 26        Oakland Raiders     5      11         2          4        AFC
# 27  Washington Commanders     4      12         0          2        NFC
# 28     Kansas City Chiefs     4      12         2          3        AFC
# 29   Tampa Bay Buccaneers     3      13         1          3        NFC
# 30          Detroit Lions     2      14         0          1        NFC
# 31         St. Louis Rams     1      15         0          1        NFC
#
#      Division  Total_Margin
# 0   AFC South           109
# 1   NFC South           169
# 2    AFC West           134
# 3   NFC North           158
# 4   NFC North           164
# 5    NFC East           111
# 6    NFC East            92
# 7    AFC East           142
# 8    NFC West            50
# 9   AFC North            14
# 10  AFC North           130
# 11   AFC East           112
# 12  AFC South            55
# 13  AFC North            44
# 14  NFC South            38
# 15   NFC West            49
# 16  NFC South             7
# 17   AFC West             2
# 18   NFC East           -25
# 19  AFC South           -48
# 20   AFC East           -30
# 21  NFC North           -48
# 22  AFC South           -90
# 23   AFC East           -68
# 24   NFC West          -110
# 25  AFC North          -130
# 26   AFC West          -182
# 27   NFC East           -70
# 28   AFC West          -130
# 29  NFC South          -156
# 30  NFC North          -232
# 31   NFC West          -261
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2010 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1  New England Patriots   AFC East    14       2
# 1         AFC     2   Pittsburgh Steelers  AFC North    12       4
# 2         AFC     3    Indianapolis Colts  AFC South    10       6
# 3         AFC     4    Kansas City Chiefs   AFC West    10       6
# 4         AFC     5      Baltimore Ravens  AFC North    12       4
# 5         AFC     6         New York Jets   AFC East    11       5
# 6         AFC     7    San Diego Chargers   AFC West     9       7
# 7         NFC     1       Atlanta Falcons  NFC South    13       3
# 8         NFC     2         Chicago Bears  NFC North    11       5
# 9         NFC     3   Philadelphia Eagles   NFC East    10       6
# 10        NFC     4      Seattle Seahawks   NFC West     7       9
# 11        NFC     5    New Orleans Saints  NFC South    11       5
# 12        NFC     6     Green Bay Packers  NFC North    10       6
# 13        NFC     7       New York Giants   NFC East    10       6
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0    New England Patriots    14       2         5         10        AFC
# 1         Atlanta Falcons    13       3         5         10        NFC
# 2     Pittsburgh Steelers    12       4         5          9        AFC
# 3        Baltimore Ravens    12       4         4          9        AFC
# 4      New Orleans Saints    11       5         4          9        NFC
# 5           New York Jets    11       5         4          9        AFC
# 6           Chicago Bears    11       5         5          8        NFC
# 7       Green Bay Packers    10       6         4          8        NFC
# 8     Philadelphia Eagles    10       6         4          7        NFC
# 9      Indianapolis Colts    10       6         4          8        AFC
# 10        New York Giants    10       6         3          8        NFC
# 11     Kansas City Chiefs    10       6         2          6        AFC
# 12   Tampa Bay Buccaneers    10       6         3          8        NFC
# 13     San Diego Chargers     9       7         3          7        AFC
# 14        Oakland Raiders     8       8         6          6        AFC
# 15   Jacksonville Jaguars     8       8         3          7        AFC
# 16         St. Louis Rams     7       9         3          5        NFC
# 17         Miami Dolphins     7       9         2          5        AFC
# 18       Seattle Seahawks     7       9         4          6        NFC
# 19       Tennessee Titans     6      10         2          3        AFC
# 20          Detroit Lions     6      10         2          5        NFC
# 21         Houston Texans     6      10         3          5        AFC
# 22    San Francisco 49ers     6      10         4          4        NFC
# 23         Dallas Cowboys     6      10         3          4        NFC
# 24      Minnesota Vikings     6      10         1          5        NFC
# 25  Washington Commanders     6      10         2          4        NFC
# 26       Cleveland Browns     5      11         1          3        AFC
# 27      Arizona Cardinals     5      11         1          3        NFC
# 28     Cincinnati Bengals     4      12         2          3        AFC
# 29         Denver Broncos     4      12         1          3        AFC
# 30          Buffalo Bills     4      12         1          3        AFC
# 31      Carolina Panthers     2      14         0          2        NFC
#
#      Division  Total_Margin
# 0    AFC East           205
# 1   NFC South           126
# 2   AFC North           143
# 3   AFC North            87
# 4   NFC South            77
# 5    AFC East            63
# 6   NFC North            48
# 7   NFC North           148
# 8    NFC East            62
# 9   AFC South            47
# 10   NFC East            47
# 11   AFC West            40
# 12  NFC South            23
# 13   AFC West           119
# 14   AFC West            39
# 15  AFC South           -66
# 16   NFC West           -39
# 17   AFC East           -60
# 18   NFC West           -97
# 19  AFC South            17
# 20  NFC North            -7
# 21  AFC South           -37
# 22   NFC West           -41
# 23   NFC East           -42
# 24  NFC North           -67
# 25   NFC East           -75
# 26  AFC North           -61
# 27   NFC West          -145
# 28  AFC North           -73
# 29   AFC West          -127
# 30   AFC East          -142
# 31  NFC South          -212
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2011 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1  New England Patriots   AFC East    13       3
# 1         AFC     2      Baltimore Ravens  AFC North    12       4
# 2         AFC     3        Houston Texans  AFC South    10       6
# 3         AFC     4        Denver Broncos   AFC West     8       8
# 4         AFC     5   Pittsburgh Steelers  AFC North    12       4
# 5         AFC     6    Cincinnati Bengals  AFC North     9       7
# 6         AFC     7      Tennessee Titans  AFC South     9       7
# 7         NFC     1     Green Bay Packers  NFC North    15       1
# 8         NFC     2   San Francisco 49ers   NFC West    13       3
# 9         NFC     3    New Orleans Saints  NFC South    13       3
# 10        NFC     4       New York Giants   NFC East     9       7
# 11        NFC     5       Atlanta Falcons  NFC South    10       6
# 12        NFC     6         Detroit Lions  NFC North    10       6
# 13        NFC     7         Chicago Bears  NFC North     8       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0       Green Bay Packers    15       1         6         12        NFC
# 1      New Orleans Saints    13       3         5          9        NFC
# 2    New England Patriots    13       3         5         10        AFC
# 3     San Francisco 49ers    13       3         5         10        NFC
# 4        Baltimore Ravens    12       4         6          9        AFC
# 5     Pittsburgh Steelers    12       4         4          9        AFC
# 6          Houston Texans    10       6         4          8        AFC
# 7           Detroit Lions    10       6         3          6        NFC
# 8         Atlanta Falcons    10       6         3          7        NFC
# 9      Cincinnati Bengals     9       7         2          6        AFC
# 10       Tennessee Titans     9       7         3          7        AFC
# 11        New York Giants     9       7         3          5        NFC
# 12    Philadelphia Eagles     8       8         5          6        NFC
# 13     San Diego Chargers     8       8         3          7        AFC
# 14         Dallas Cowboys     8       8         2          6        NFC
# 15          New York Jets     8       8         3          6        AFC
# 16          Chicago Bears     8       8         3          7        NFC
# 17      Arizona Cardinals     8       8         4          7        NFC
# 18        Oakland Raiders     8       8         3          6        AFC
# 19         Denver Broncos     8       8         3          6        AFC
# 20       Seattle Seahawks     7       9         3          6        NFC
# 21     Kansas City Chiefs     7       9         3          4        AFC
# 22         Miami Dolphins     6      10         3          5        AFC
# 23      Carolina Panthers     6      10         2          3        NFC
# 24          Buffalo Bills     6      10         1          4        AFC
# 25  Washington Commanders     5      11         2          5        NFC
# 26   Jacksonville Jaguars     5      11         3          4        AFC
# 27       Cleveland Browns     4      12         0          3        AFC
# 28   Tampa Bay Buccaneers     4      12         2          3        NFC
# 29      Minnesota Vikings     3      13         0          3        NFC
# 30     Indianapolis Colts     2      14         2          2        AFC
# 31         St. Louis Rams     2      14         0          1        NFC
#
#      Division  Total_Margin
# 0   NFC North           201
# 1   NFC South           208
# 2    AFC East           171
# 3    NFC West           151
# 4   AFC North           112
# 5   AFC North            98
# 6   AFC South           103
# 7   NFC North            87
# 8   NFC South            52
# 9   AFC North            21
# 10  AFC South             8
# 11   NFC East            -6
# 12   NFC East            68
# 13   AFC West            29
# 14   NFC East            22
# 15   AFC East            14
# 16  NFC North            12
# 17   NFC West           -36
# 18   AFC West           -74
# 19   AFC West           -81
# 20   NFC West             6
# 21   AFC West          -126
# 22   AFC East            16
# 23  NFC South           -23
# 24   AFC East           -62
# 25   NFC East           -79
# 26  AFC South           -86
# 27  AFC North           -89
# 28  NFC South          -207
# 29  NFC North          -109
# 30  AFC South          -187
# 31   NFC West          -214
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2012 Playoff field
#    Conference  Seed                   Team   Division  Wins  Losses
# 0         AFC     1         Denver Broncos   AFC West    13       3
# 1         AFC     2   New England Patriots   AFC East    12       4
# 2         AFC     3         Houston Texans  AFC South    12       4
# 3         AFC     4       Baltimore Ravens  AFC North    10       6
# 4         AFC     5     Indianapolis Colts  AFC South    11       5
# 5         AFC     6     Cincinnati Bengals  AFC North    10       6
# 6         AFC     7    Pittsburgh Steelers  AFC North     8       8
# 7         NFC     1        Atlanta Falcons  NFC South    13       3
# 8         NFC     2    San Francisco 49ers   NFC West    11       4
# 9         NFC     3      Green Bay Packers  NFC North    11       5
# 10        NFC     4  Washington Commanders   NFC East    10       6
# 11        NFC     5       Seattle Seahawks   NFC West    11       5
# 12        NFC     6      Minnesota Vikings  NFC North    10       6
# 13        NFC     7          Chicago Bears  NFC North    10       6
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0          Denver Broncos    13       3         6         10        AFC
# 1         Atlanta Falcons    13       3         3          9        NFC
# 2    New England Patriots    12       4         6         11        AFC
# 3          Houston Texans    12       4         5         10        AFC
# 4        Seattle Seahawks    11       5         3          8        NFC
# 5     San Francisco 49ers    11       4         3          7        NFC
# ...
# 19     New Orleans Saints     7      10         2          5        NFC
# 20       Cleveland Browns     7      10         3          4        AFC
# 21          New York Jets     7      10         2          5        AFC
# 22        Atlanta Falcons     7      10         2          6        NFC
# 23      Carolina Panthers     7      10         4          6        NFC
# 24       Tennessee Titans     7      10         3          5        AFC
# 25      Las Vegas Raiders     6      11         3          5        AFC
# 26         Denver Broncos     5      12         1          3        AFC
# 27       Los Angeles Rams     5      12         1          3        NFC
# 28      Arizona Cardinals     4      13         1          3        NFC
# 29     Indianapolis Colts     4      12         1          4        AFC
# 30         Houston Texans     3      13         3          3        AFC
# 31          Chicago Bears     3      14         0          1        NFC
#
#      Division  Total_Margin
# 0    NFC East           133
# 1    AFC West           127
# 2    NFC West           173
# 3    AFC East           169
# 4   NFC North            -3
# 5    NFC East           125
# 6   AFC North            96
# 7   AFC North            35
# 8    AFC West             7
# 9   AFC South            54
# 10  NFC North            26
# 11   NFC West             6
# 12   AFC East            -2
# 13   NFC East            -6
# 14  AFC North           -38
# 15   AFC East            17
# 16  NFC North            -1
# 17   NFC East           -22
# 18  NFC South           -45
# 19  NFC South           -15
# 20  AFC North           -20
# 21   AFC East           -20
# 22  NFC South           -21
# 23  NFC South           -27
# 24  AFC South           -61
# 25   AFC West           -23
# 26   AFC West           -72
# 27   NFC West           -77
# 28   NFC West          -109
# 29  AFC South          -138
# 30  AFC South          -131
# 31  NFC North          -137
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2023 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1      Baltimore Ravens  AFC North    13       4
# 1         AFC     2         Buffalo Bills   AFC East    11       6
# 2         AFC     3    Kansas City Chiefs   AFC West    11       6
# 3         AFC     4        Houston Texans  AFC South    10       7
# 4         AFC     5      Cleveland Browns  AFC North    11       6
# 5         AFC     6        Miami Dolphins   AFC East    11       6
# 6         AFC     7   Pittsburgh Steelers  AFC North    10       7
# 7         NFC     1   San Francisco 49ers   NFC West    12       5
# 8         NFC     2        Dallas Cowboys   NFC East    12       5
# 9         NFC     3         Detroit Lions  NFC North    12       5
# 10        NFC     4  Tampa Bay Buccaneers  NFC South     9       8
# 11        NFC     5   Philadelphia Eagles   NFC East    11       6
# 12        NFC     6      Los Angeles Rams   NFC West    10       7
# 13        NFC     7     Green Bay Packers  NFC North     9       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0        Baltimore Ravens    13       4         3          8        AFC
# 1          Dallas Cowboys    12       5         5          9        NFC
# 2     San Francisco 49ers    12       5         5         10        NFC
# 3           Detroit Lions    12       5         4          8        NFC
# 4           Buffalo Bills    11       6         4          7        AFC
# 5          Miami Dolphins    11       6         4          7        AFC
# 6      Kansas City Chiefs    11       6         4          9        AFC
# 7        Cleveland Browns    11       6         3          8        AFC
# 8     Philadelphia Eagles    11       6         4          7        NFC
# 9        Los Angeles Rams    10       7         5          8        NFC
# 10         Houston Texans    10       7         4          7        AFC
# 11    Pittsburgh Steelers    10       7         5          7        AFC
# 12     New Orleans Saints     9       8         4          6        NFC
# 13      Green Bay Packers     9       8         4          7        NFC
# 14   Tampa Bay Buccaneers     9       8         4          7        NFC
# 15   Jacksonville Jaguars     9       8         4          6        AFC
# 16     Cincinnati Bengals     9       8         1          4        AFC
# 17     Indianapolis Colts     9       8         3          7        AFC
# 18       Seattle Seahawks     9       8         2          7        NFC
# 19      Las Vegas Raiders     8       9         4          6        AFC
# 20         Denver Broncos     8       9         3          5        AFC
# 21      Minnesota Vikings     7      10         2          6        NFC
# 22          Chicago Bears     7      10         2          6        NFC
# 23        Atlanta Falcons     7      10         3          4        NFC
# 24          New York Jets     7      10         2          4        AFC
# 25       Tennessee Titans     6      11         1          4        AFC
# 26        New York Giants     6      11         3          5        NFC
# 27   Los Angeles Chargers     5      12         1          3        AFC
# 28      Arizona Cardinals     4      13         0          3        NFC
# 29   New England Patriots     4      13         2          4        AFC
# 30  Washington Commanders     4      13         0          2        NFC
# 31      Carolina Panthers     2      15         1          1        NFC
#
#      Division  Total_Margin
# 0   AFC North           203
# 1    NFC East           194
# 2    NFC West           193
# 3   NFC North            66
# 4    AFC East           140
# 5    AFC East           105
# 6    AFC West            77
# 7   AFC North            34
# 8    NFC East             5
# 9    NFC West            27
# 10  AFC South            24
# 11  AFC North           -20
# 12  NFC South            75
# 13  NFC North            33
# 14  NFC South            23
# 15  AFC South             6
# 16  AFC North           -18
# 17  AFC South           -19
# 18   NFC West           -38
# 19   AFC West             1
# 20   AFC West           -56
# 21  NFC North           -18
# 22  NFC North           -19
# 23  NFC South           -52
# 24   AFC East           -87
# 25  AFC South           -62
# 26   NFC East          -141
# 27   AFC West           -52
# 28   NFC West          -125
# 29   AFC East          -130
# 30   NFC East          -189
# 31  NFC South          -180
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2024 Playoff field
#    Conference  Seed                   Team   Division  Wins  Losses
# 0         AFC     1     Kansas City Chiefs   AFC West    15       2
# 1         AFC     2          Buffalo Bills   AFC East    13       4
# 2         AFC     3       Baltimore Ravens  AFC North    12       5
# 3         AFC     4         Houston Texans  AFC South    10       7
# 4         AFC     5   Los Angeles Chargers   AFC West    11       6
# 5         AFC     6    Pittsburgh Steelers  AFC North    10       7
# 6         AFC     7         Denver Broncos   AFC West    10       7
# 7         NFC     1          Detroit Lions  NFC North    15       2
# 8         NFC     2    Philadelphia Eagles   NFC East    14       3
# 9         NFC     3   Tampa Bay Buccaneers  NFC South    10       7
# 10        NFC     4       Los Angeles Rams   NFC West    10       7
# 11        NFC     5      Minnesota Vikings  NFC North    14       3
# 12        NFC     6  Washington Commanders   NFC East    12       5
# 13        NFC     7      Green Bay Packers  NFC North    11       6
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0           Detroit Lions    15       2         6         11        NFC
# 1      Kansas City Chiefs    15       2         5         10        AFC
# 2     Philadelphia Eagles    14       3         5          9        NFC
# 3       Minnesota Vikings    14       3         4          9        NFC
# 4           Buffalo Bills    13       4         5          9        AFC
# 5        Baltimore Ravens    12       5         4          8        AFC
# 6   Washington Commanders    12       5         4          9        NFC
# 7       Green Bay Packers    11       6         1          6        NFC
# 8    Los Angeles Chargers    11       6         4          8        AFC
# 9    Tampa Bay Buccaneers    10       7         4          8        NFC
# 10         Denver Broncos    10       7         3          6        AFC
# 11    Pittsburgh Steelers    10       7         3          7        AFC
# 12       Seattle Seahawks    10       7         4          6        NFC
# 13         Houston Texans    10       7         5          8        AFC
# 14       Los Angeles Rams    10       7         4          6        NFC
# 15     Cincinnati Bengals     9       8         3          6        AFC
# 16      Arizona Cardinals     8       9         3          4        NFC
# 17         Miami Dolphins     8       9         3          6        AFC
# 18        Atlanta Falcons     8       9         4          7        NFC
# 19     Indianapolis Colts     8       9         3          7        AFC
# 20         Dallas Cowboys     7      10         3          5        NFC
# 21    San Francisco 49ers     6      11         1          4        NFC
# 22          Chicago Bears     5      12         1          3        NFC
# 23     New Orleans Saints     5      12         2          4        NFC
# 24          New York Jets     5      12         2          5        AFC
# 25      Carolina Panthers     5      12         2          4        NFC
# 26   Jacksonville Jaguars     4      13         3          4        AFC
# 27      Las Vegas Raiders     4      13         0          3        AFC
# 28   New England Patriots     4      13         2          3        AFC
# 29        New York Giants     3      14         0          1        NFC
# 30       Tennessee Titans     3      14         1          3        AFC
# 31       Cleveland Browns     3      14         2          3        AFC
#
#      Division  Total_Margin
# 0   NFC North           222
# 1    AFC West            59
# 2    NFC East           160
# 3   NFC North           100
# 4    AFC East           157
# 5   AFC North           157
# 6    NFC East            94
# 7   NFC North           122
# 8    AFC West           101
# 9   NFC South           117
# 10   AFC West           114
# 11  AFC North            33
# 12   NFC West             7
# 13  AFC South             0
# 14   NFC West           -19
# 15  AFC North            38
# 16   NFC West            21
# 17   AFC East           -19
# 18  NFC South           -34
# 19  AFC South           -50
# 20   NFC East          -118
# 21   NFC West           -47
# 22  NFC North           -60
# 23  NFC South           -60
# 24   AFC East           -66
# 25  NFC South          -193
# 26  AFC South          -115
# 27   AFC West          -125
# 28   AFC East          -128
# 29   NFC East          -142
# 30  AFC South          -149
# 31  AFC North          -177
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# TIEBREAKER CALLED
# 2025 Playoff field
#    Conference  Seed                  Team   Division  Wins  Losses
# 0         AFC     1        Denver Broncos   AFC West    14       3
# 1         AFC     2  New England Patriots   AFC East    14       3
# 2         AFC     3  Jacksonville Jaguars  AFC South    13       4
# 3         AFC     4   Pittsburgh Steelers  AFC North    10       7
# 4         AFC     5        Houston Texans  AFC South    12       5
# 5         AFC     6         Buffalo Bills   AFC East    12       5
# 6         AFC     7  Los Angeles Chargers   AFC West    11       6
# 7         NFC     1      Seattle Seahawks   NFC West    14       3
# 8         NFC     2         Chicago Bears  NFC North    11       6
# 9         NFC     3   Philadelphia Eagles   NFC East    11       6
# 10        NFC     4  Tampa Bay Buccaneers  NFC South     8       9
# 11        NFC     5      Los Angeles Rams   NFC West    12       5
# 12        NFC     6   San Francisco 49ers   NFC West    12       5
# 13        NFC     7     Minnesota Vikings  NFC North     9       8
#                      Team  Wins  Losses  Div_Wins  Conf_Wins Conference  \
# 0        Seattle Seahawks    14       3         4          9        NFC
# 1    New England Patriots    14       3         5          9        AFC
# 2          Denver Broncos    14       3         5          9        AFC
# 3    Jacksonville Jaguars    13       4         5         10        AFC
# 4        Los Angeles Rams    12       5         4          7        NFC
# 5           Buffalo Bills    12       5         4          9        AFC
# 6          Houston Texans    12       5         5         10        AFC
# 7     San Francisco 49ers    12       5         4          9        NFC
# 8     Philadelphia Eagles    11       6         3          8        NFC
# 9    Los Angeles Chargers    11       6         5          8        AFC
# 10          Chicago Bears    11       6         2          7        NFC
# 11    Pittsburgh Steelers    10       7         4          8        AFC
# 12          Detroit Lions     9       8         2          6        NFC
# 13      Green Bay Packers     9       7         4          7        NFC
# 14      Minnesota Vikings     9       8         4          7        NFC
# 15     Indianapolis Colts     8       9         2          6        AFC
# 16       Baltimore Ravens     8       9         3          5        AFC
# 17   Tampa Bay Buccaneers     8       9         3          6        NFC
# 18        Atlanta Falcons     8       9         3          7        NFC
# 19      Carolina Panthers     8       9         3          6        NFC
# 20         Dallas Cowboys     7       9         4          4        NFC
# 21         Miami Dolphins     7      10         3          3        AFC
# 22     Kansas City Chiefs     6      11         1          3        AFC
# 23     New Orleans Saints     6      11         3          4        NFC
# 24     Cincinnati Bengals     6      11         3          5        AFC
# 25  Washington Commanders     5      12         3          3        NFC
# 26       Cleveland Browns     5      12         2          4        AFC
# 27        New York Giants     4      13         2          2        NFC
# 28      Arizona Cardinals     3      14         0          3        NFC
# 29      Las Vegas Raiders     3      14         1          3        AFC
# 30       Tennessee Titans     3      14         0          2        AFC
# 31          New York Jets     3      14         0          2        AFC
#
#      Division  Total_Margin
# 0    NFC West           191
# 1    AFC East           170
# 2    AFC West            90
# 3   AFC South           138
# 4    NFC West           172
# 5    AFC East           116
# 6   AFC South           109
# 7    NFC West            66
# 8    NFC East            54
# 9    AFC West            28
# 10  NFC North            26
# 11  AFC North            10
# 12  NFC North            68
# 13  NFC North            31
# 14  NFC North            11
# 15  AFC South            54
# 16  AFC North            26
# 17  NFC South           -31
# 18  NFC South           -48
# 19  NFC South           -69
# 20   NFC East           -40
# 21   AFC East           -77
# 22   AFC West            34
# 23  NFC South           -77
# 24  AFC North           -78
# 25   NFC East           -95
# 26  AFC North          -100
# 27   NFC East           -58
# 28   NFC West          -133
# 29   AFC West          -191
# 30  AFC South          -194
# 31   AFC East          -203
# Counter({'head to head': 78, 'conference_record': 40, 'common_games': 26, 'division_record': 17, 'strength_of_victory': 7})
