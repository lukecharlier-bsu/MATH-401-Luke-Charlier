# %%
#imports
import pandas as pd
from generate_schedule import generate_schedule
from sim_season import simulate_season
from random_fpi import make_random_fpi
from playoffs import playoff_field
from collections import Counter
from real_nfl_schedule import build_real_season_dfs,real_schedule_df
import matplotlib.pyplot as plt

# %%
# 1000 sims on the same FPI/Schedule seed
n = 1000

# Fix FPI + schedule ONCE
df_seeded = make_random_fpi(df, mean=-0.016, std=2.5, seed=5)
schedule_df = generate_schedule(df_seeded, seed=1)

tb_counts = Counter()
fpi_counts = Counter()
field_count = Counter()

for sim_seed in range(1, n + 1):
    results_df, standings_df = simulate_season(df_seeded, schedule_df, seed=sim_seed)

    field, tiebreakers, fpi_winners = playoff_field(standings_df, results_df)

    tb_counts.update(Counter(tiebreakers))
    fpi_counts.update(Counter(fpi_winners))
    field_count.update(Counter(field["Team"]))

print(tb_counts)
print(fpi_counts)
#print(field_count)

field_prob_df = (pd.Series(field_count).sort_values(ascending=False).rename("Playoff_Prob").to_frame())

field_prob_df["Playoff_Prob"] = field_prob_df["Playoff_Prob"]/n
field_prob_df = field_prob_df.merge(df_seeded[["Team", "FPI"]],left_index=True,right_on="Team",how="left").set_index("Team")

print(field_prob_df)
# Out:
# Coin flip! _________-----------_____________------------_______________-------- ['Dallas Cowboys', 'San Francisco 49ers']
# Counter({'head to head': 3768, 'conference_record': 2219, 'common_games': 1016, 'division_record': 880, 'strength_of_victory': 352, 'strength_of_schedule': 9, 'Coin Flip!': 1})
# Counter({'higher FPI won': 4123, 'lower FPI won': 4122})
#                        Playoff_Prob  FPI
# Team
# Jacksonville Jaguars          0.966  4.1
# Cincinatti Bengals            0.927  4.0
# Green Bay Packers             0.862  2.8
# Arizona Cardinals             0.806  2.1
# San Francisco 49ers           0.775  1.9
# Philadelphia Eagles           0.731  1.0
# Washington Commanders         0.714  1.4
# Denver Broncos                0.677  0.7
# Carolina Panthers             0.612  1.0
# New York Jets                 0.588 -0.4
# Baltimore Ravens              0.560  0.3
# New Orleans Saints            0.519 -0.2
# Cleveland Browns              0.503  0.0
# Las Vegas Raiders             0.482 -0.7
# Chicago Bears                 0.474  0.5
# Buffalo Bills                 0.380 -1.4
# Pittsburgh Steelers           0.340 -0.2
# Detroit Lions                 0.332 -0.6
# Atlanta Falcons               0.316 -1.5
# Kansas City Chiefs            0.303 -1.2
# Indianapolis Colts            0.285 -1.8
# Los Angeles Rams              0.255 -2.0
# Tampa Bay Buccaneers          0.235 -1.6
# Houston Texans                0.219 -2.0
# Los Angeles Chargers          0.212 -2.4
# New England Patriots          0.196 -3.1
# Miami Dolphins                0.193 -3.2
# Dallas Cowboys                0.188 -2.9
# Tennessee Titans              0.169 -2.5
# Seattle Seahawks              0.064 -3.3
# New York Giants               0.059 -4.3
# Minnesota Vikings             0.058 -4.1

# %%
plt.scatter(field_prob_df["FPI"], field_prob_df["Playoff_Prob"])

plt.xlabel("FPI")
plt.ylabel("Playoff Probability")
plt.title("FPI vs Playoff Probability (1000 Sims)")
plt.axhline(0.5,alpha = 0.2)
plt.axvline(0,alpha=0.2)

plt.show()

# %%
# How well do FPIs predict playoffs?
schedule_2024 = real_schedule_df(2024)
#print(schedule_2024)
dfs = {}
for year in range(2015, 2025):
    dfs[year] = pd.read_csv(f"FPI_Years/FPI_{year}.csv")
#print(dfs[2015])
field_count = Counter()
n = 1000
for sim_seed in range(1, n + 1):
    results_2024, standings_2024 = simulate_season(dfs[2024],schedule_2024,seed = sim_seed)
    field_2024, tiebreakers_2024, fpi_2024 = playoff_field(standings_2024,results_2024)
    field_count.update(Counter(field_2024["Team"]))

field_prob_df = (pd.Series(field_count).sort_values(ascending=False).rename("Playoff_Prob").to_frame())

field_prob_df["Playoff_Prob"] = field_prob_df["Playoff_Prob"]/n
field_prob_df = field_prob_df.merge(dfs[2024][["Team", "FPI"]],left_index=True,right_on="Team",how="left").set_index("Team")

print(field_prob_df)
# Out:
#                        Playoff_Prob  FPI
# Team
# Baltimore Ravens              0.993  8.1
# Detroit Lions                 0.987  8.1
# Philadelphia Eagles           0.987  6.4
# Buffalo Bills                 0.969  6.1
# Green Bay Packers             0.926  6.2
# Tampa Bay Buccaneers          0.887  2.9
# Kansas City Chiefs            0.831  3.4
# Washington Commanders         0.753  1.5
# Houston Texans                0.663  0.3
# Los Angeles Chargers          0.623  1.0
# Minnesota Vikings             0.604  2.4
# Cincinnati Bengals            0.577  0.8
# Miami Dolphins                0.532  0.5
# San Francisco 49ers           0.489  2.2
# Los Angeles Rams              0.411  1.3
# Pittsburgh Steelers           0.394  0.4
# Atlanta Falcons               0.392 -1.0
# Denver Broncos                0.376 -0.4
# New York Jets                 0.311 -0.9
# Arizona Cardinals             0.288  0.4
# Tennessee Titans              0.219 -2.7
# Seattle Seahawks              0.195 -0.6
# Indianapolis Colts            0.189 -3.3
# Las Vegas Raiders             0.149 -2.4
# Cleveland Browns              0.111 -2.5
# Chicago Bears                 0.061 -2.2
# Jacksonville Jaguars          0.049 -5.4
# New England Patriots          0.014 -5.6
# Dallas Cowboys                0.011 -5.7
# New Orleans Saints            0.008 -7.4
# Carolina Panthers             0.001 -9.0

# %%
# Out:
# 2015 Rams rows left: 1
# 2016 Rams rows left: 1
# 2017 Rams rows left: 1
# 2018 Rams rows left: 1
# 2019 Rams rows left: 1
# 2020 Rams rows left: 1
# 2021 Rams rows left: 1
# 2022 Rams rows left: 1
# 2023 Rams rows left: 1
# 2024 Rams rows left: 1
# Extra Rams removed from all files.
