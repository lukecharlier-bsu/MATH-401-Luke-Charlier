# %%
# !python main.py
# Out:
# ------------------------------------------------------
# SEASON SIMULATION (seed = 1)
# ------------------------------------------------------
#
# STANDINGS:
#                      Team  Wins  Losses  FPI  Div_Wins  Conf_Wins   Division  Total_Margin Conference  FPI vs True difference
# 0      New Orleans Saints    14       3  3.2         6         10  NFC South    107.443802        NFC                       1
# 1     San Francisco 49ers    13       4  0.9         5          8   NFC West     58.975150        NFC                       8
# 2     Pittsburgh Steelers    12       5  0.1         5          8  AFC North     55.373014        AFC                      13
# 3          Houston Texans    12       5  1.4         4          8  AFC South     40.592893        AFC                       3
# 4        Seattle Seahawks    12       5  2.0         4          7   NFC West     34.354703        NFC                       0
# ...

# %%
def my_function(x):
    """
    This is a docstring
    Input: x
    Output: None
    Use: prints the input
    """
    print(x)

# %%
my_function("Hello World!")
# ?my_function
# Out:
# Hello World!
# Signature: my_function(x)
# Docstring:
# This is a docstring
# Input: x
# Output: None
# Use: prints the input
# File:      /var/folders/c5/9vgy5ksj515778rgdgn7t66c0000gn/T/ipykernel_46796/1067655108.py
# Type:      function
