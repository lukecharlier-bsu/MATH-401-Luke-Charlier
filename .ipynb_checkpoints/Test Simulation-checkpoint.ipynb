# %%
# !python main.py
# Out:
# ------------------------------------------------------
# SEASON SIMULATION (seed = 1)
# ------------------------------------------------------
#
# STANDINGS:
#                      Team  Wins  Losses  FPI  Div_Wins  Conf_Wins   Division Conference  FPI vs True difference
# 0      New Orleans Saints    14       3  3.2         6         10  NFC South        NFC                       1
# 1     San Francisco 49ers    13       4  0.9         5          8   NFC West        NFC                       8
# 2     Pittsburgh Steelers    12       5  0.1         5          8  AFC North        AFC                      13
# 3          Houston Texans    12       5  1.4         4          8  AFC South        AFC                       3
# 4        Seattle Seahawks    12       5  2.0         4          7   NFC West        NFC                       0
# 5         New York Giants    12       5  1.5         5          9   NFC East        NFC                       0
# ...
