# %%
# !python main.py
# Out:
# Counter({'head to head': 78, 'conference_record': 51, 'division_record': 20, 'common_games': 19, 'strength_of_victory': 4})
# Counter({'higher FPI won': 86, 'lower FPI won': 86})
# Counter({'head to head': 71, 'conference_record': 37, 'common_games': 23, 'division_record': 15, 'win percentage diff': 15, 'strength_of_victory': 7})

# %%
def my_function(x):
    """
    This is a docstring
    Input: x
    Output: None
    Use: prints the input
    """
    print(x)

# %%
my_function("Hello World!")
# ?my_function
# Out:
# Hello World!
# Signature: my_function(x)
# Docstring:
# This is a docstring
# Input: x
# Output: None
# Use: prints the input
# File:      /var/folders/c5/9vgy5ksj515778rgdgn7t66c0000gn/T/ipykernel_46796/1067655108.py
# Type:      function
