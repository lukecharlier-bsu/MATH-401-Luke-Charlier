# %%
# !python main.py
# Out:
#                      Team  Wins  Losses  FPI  Div_Wins  Conf_Wins  FPI vs True difference
# 0          Miami Dolphins    14       3  5.2         5         11                       0
# 1       Minnesota Vikings    13       4 -0.4         5          9                      18
# 2         Atlanta Falcons    13       4  2.5         3          8                       0
# 3          Denver Broncos    13       4  0.1         4          9                      13
# 4      New Orleans Saints    12       5  3.2         6         10                      -3
# 5       Las Vegas Raiders    11       6 -1.1         3          7                      18
# 6        Seattle Seahawks    11       6  2.0         5          8                      -2
# 7        Tennessee Titans    10       7  0.5         5          8                       7
# 8       Green Bay Packers    10       7  2.2         3          6                      -5
# ...
