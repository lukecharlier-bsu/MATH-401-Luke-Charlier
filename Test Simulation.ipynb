# %%
# !python main.py
# Out:
# ------------------------------------------------------
# SEASON SIMULATION (seed = 2002)
# ------------------------------------------------------
#    Conference  Seed                  Team   Division  Wins  Losses  Ties
# 0         AFC     1         Buffalo Bills   AFC East    13       4     0
# 1         AFC     2    Kansas City Chiefs   AFC West    11       6     0
# 2         AFC     3   Pittsburgh Steelers  AFC North    10       7     0
# 3         AFC     4        Houston Texans  AFC South     9       8     0
# 4         AFC     5        Miami Dolphins   AFC East    12       5     0
# 5         AFC     6     Las Vegas Raiders   AFC West    10       7     0
# 6         AFC     7  New England Patriots   AFC East     8       9     0
# 7         NFC     1     Arizona Cardinals   NFC West    15       2     0
# 8         NFC     2       New York Giants   NFC East    12       5     0
# 9         NFC     3     Green Bay Packers  NFC North    11       6     0
# ...

# %%
def my_function(x):
    """
    This is a docstring
    Input: x
    Output: None
    Use: prints the input
    """
    print(x)

# %%
my_function("Hello World!")
# ?my_function
# Out:
# Hello World!
# Signature: my_function(x)
# Docstring:
# This is a docstring
# Input: x
# Output: None
# Use: prints the input
# File:      /var/folders/c5/9vgy5ksj515778rgdgn7t66c0000gn/T/ipykernel_46796/1067655108.py
# Type:      function
