# %%
# !python main.py
# Out:
# ------------------------------------------------------
# SEASON SIMULATION (seed = 2002)
# ------------------------------------------------------
#
# STANDINGS:
#                      Team  Wins  Losses  FPI  Div_Wins  Conf_Wins   Division  Total_Margin Conference  FPI vs True difference
# 0       Arizona Cardinals    15       2  2.5         6         10   NFC West    112.658326        NFC                       5
# 1           Buffalo Bills    13       4  1.8         5         10   AFC East     69.006436        AFC                       9
# 2          Miami Dolphins    12       5  2.3         4          8   AFC East     33.589502        AFC                       5
# 3         New York Giants    12       5  4.9         4          8   NFC East     85.959020        NFC                      -2
# 4       Green Bay Packers    11       6  2.5         5          7  NFC North     89.608546        NFC                       0
# ...

# %%
def my_function(x):
    """
    This is a docstring
    Input: x
    Output: None
    Use: prints the input
    """
    print(x)

# %%
my_function("Hello World!")
# ?my_function
# Out:
# Hello World!
# Signature: my_function(x)
# Docstring:
# This is a docstring
# Input: x
# Output: None
# Use: prints the input
# File:      /var/folders/c5/9vgy5ksj515778rgdgn7t66c0000gn/T/ipykernel_46796/1067655108.py
# Type:      function
